# %%
import pandas as pd

# %%
import numpy as np

# %%
filtered = pd.read_csv("filtered_gene_counts.csv")

# %%
filtered.loc[:,filtered.columns[1:]] = filtered.filter(regex='^(SRR*)', axis=1).round().astype('int64') + 1

# %%
filtered
# Out:
#                refseq  SRR3438884  SRR3438860  SRR3438634  SRR3438649  \
# 0      NM_001005484.2          11           1           1           1
# 1         NM_152486.4          29          39          17         122
# 2         NM_015658.4        4227        4566        2510        2040
# 3         NM_198317.3         895         770         638         299
# 4         NM_032129.3           1           1           1           7
# ...               ...         ...         ...         ...         ...
# 17157     NM_005198.5         995        1565         662         628
# 17158     NM_012324.6       28160       31235       30284       23034
# 17159     NM_000487.6        1745        1675        1934        1708
# 17160     NM_001097.3          32          51          18          26
# 17161  NM_001003789.3         158         385          35          74
#
#        SRR3438578  SRR3438825  SRR3438792  SRR3438695  SRR3438897  ...  \
# 0               1           6           1          28          37  ...
# 1              11          27          37          33         126  ...
# 2            2184        4418        7483        5263        2600  ...
# 3             382        1012        1228        1057         348  ...
# 4               2           1           1          18           1  ...
# ...           ...         ...         ...         ...         ...  ...
# 17157         461        1516        1271        1466        1085  ...
# 17158       20057       30827       78720       34283       10432  ...
# 17159         851        2090        2645        1529        1369  ...
# 17160          20          45          42          61          74  ...
# 17161          12          83         151          99         118  ...
#
#        SRR3438779  SRR3438906  SRR3438655  SRR3438752  SRR3438628  SRR3438839  \
# 0               2           1           1          16           1          20
# 1             577           3         157         406          51          23
# 2            5581        1815        1425        4629        2062        3406
# 3            1065         231         246         672         411         586
# 4               1           1           1           1           1           1
# ...           ...         ...         ...         ...         ...         ...
# 17157        2420         598         460        1555         613        1049
# 17158       24869        8797       13951       27589       19783       33982
# 17159        2655         640        1006        1901         814        1079
# 17160         101           8          36         123          21          24
# 17161         168         140          83         166           1         191
#
#        SRR3438564  SRR3438689  SRR3438610  SRR3438717
# 0               1           1           1          16
# 1              14           1           1          29
# 2            2288           2        2113        5426
# 3             580           1         444         790
# 4               1           1           1           1
# ...           ...         ...         ...         ...
# 17157         686           1         406        1191
# 17158       20646           1       19951       33053
# 17159        1175           1         923        2189
# 17160          16           1          10          50
# 17161          99           1          25         189
#
# [17162 rows x 353 columns]

# %%
filtered.to_csv("filtered.csv",index=False)
